# %% [markdown]
# <a href="https://colab.research.google.com/github/hadifirfan197-dot/2DKBCIKGUAZZA014/blob/main/PhythonCikguAzza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Phyton!")
print("Selamat datang ke latihan Phyton")
# Out:
# Hello, Phyton!
# Selamat datang ke latihan Phyton

# %% [markdown]
# PENGENALAN

# %%
nama = "Ali"
umur = 20
tinggi = 1.7

print(nama)
print(umur)
print(tinggi)

Ali
20
1.7
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1685/1750560113.py in <cell line: 0>()
# ----> 1 from _typeshed import AnyOrLiteralStr
#       2 nama = "Ali"
#       3 umur = 20
#       4 tinggi = 1.7
#       5
#
# ModuleNotFoundError: No module named '_typeshed'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
nama = input("Masukkan nama Anda: ")
print("Halo, " + nama + "! Selamat datang di Phyton!
Masukkan nama anda : Hadif
      SELAMAT DATANG HADIF
# Out:
#   File "/tmp/ipykernel_1685/3034213562.py", line 2
#     print("Halo, " + nama + "! Selamat datang di Phyton!
#                             ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
nombor1 = 10
nombor2 = 5

print(nombor1 + nombor2)
print(nombor1 - nombor2)
print(nombor1 * nombor2)
print(nombor1 / nombor2)
# Out:
# 15
# 5
# 50
# 2.0

# %% [markdown]
# operation maths

# %%
markah = int(input("Masukkan markah anda: "))  # Minta input daripada pengguna

if markah >= 80:
    print("Gred A.")
elif markah >= 60:
    print("Gred B.")
elif markah >= 40:
    print("Gred C.")
else:
    print("Gagal")
# Out:
# Masukkan markah anda: 79
# Gred B.

# %% [markdown]
# Markah

# %%
for nombor in range(1,6):
  print(nombor)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Gelung for

# %%
nombor = 1
while nombor <= 5:
    print(nombor)
    nombor = nombor + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Gelung while

# %%
def salam(nama):
  print("Selamat datang", nama)

salam("Ali")
salam("Siti")
# Out:
# Selamat datang Ali
# Selamat datang Siti

# %% [markdown]
# Fungsi

# %%
nombor1 = float(input("Masukkan nombor pertama: "))
nombor2 = float(input("Masukkan nombor kedua: "))

jumlah = nombor1 + nombor2
print("jumlah ialah:", jumlah)
# Out:
# Masukkan nombor pertama: 66
# Masukkan nombor kedua: 99
# jumlah ialah: 165.0
